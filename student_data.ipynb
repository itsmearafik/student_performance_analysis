# %% [markdown]
# # Student Academic Performance Analysis with Pandas
#
# * Import libraries and dataset
# * Add column for Total Scores, Percentage Score, Status
# * Correct and Rename column names.
# * Remove column "School" for anonymity
# * Save dataset to CSV

# %%
# Impoprting Libraries
import pandas as pd 

# loading dataset 
df = pd.read_csv("https://raw.githubusercontent.com/ritaafrica/data/refs/heads/main/student_scores.csv")

# Displaying the first 5 rows to ensure data was loaded correctly 
df.head()
# Out:
#    StudentID             Name   Country  Gender  Age  Math_Score  \
# 0          1  Ifeanyi Mugisha  Zimbabwe  Female   18          99
# 1          2       Yemi Okeke  Tanzania    Male   16          60
# 2          3    Fatou Mugisha  Zimbabwe    Male   15          49
# 3          4   Chinedu Okafor  Ethiopia  Female   17          34
# 4          5        Yemi Moyo   Senegal    Male   16          22
#
#    Reading_Score  Writing_Score                 School Class
# 0             77             12  Nelson Mandela School  JSS1
# 1             29             98         Ubuntu Academy  JSS2
# 2             46             84         Ubuntu Academy   SS3
# 3             57             45         Ubuntu Academy   SS2
# 4             16             38         Ubuntu Academy   SS3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StudentID      100 non-null    int64
#  1   Name           100 non-null    object
#  2   Country        100 non-null    object
#  3   Gender         100 non-null    object
#  4   Age            100 non-null    int64
#  5   Math_Score     100 non-null    int64
#  6   Reading_Score  100 non-null    int64
#  7   Writing_Score  100 non-null    int64
#  8   School         100 non-null    object
#  9   Class          100 non-null    object
#  10  Total_Scores   100 non-null    int64
# dtypes: int64(6), object(5)
# memory usage: 8.7+ KB

# %%
df.describe()
# Out:
#         StudentID         Age  Math_Score  Reading_Score  Writing_Score  \
# count  100.000000  100.000000  100.000000     100.000000     100.000000
# mean    50.500000   16.190000   55.780000      49.960000      50.410000
# std     29.011492    1.433333   28.786073      26.774373      27.849558
# min      1.000000   14.000000    3.000000       0.000000       1.000000
# 25%     25.750000   15.000000   30.000000      25.000000      32.000000
# 50%     50.500000   16.000000   57.000000      51.500000      47.000000
# 75%     75.250000   18.000000   82.500000      67.250000      73.250000
# max    100.000000   18.000000  100.000000     100.000000      98.000000
#
#        Total_Scores
# count    100.000000
# mean     156.150000
# std       42.829088
# min       24.000000
# 25%      126.500000
# 50%      156.500000
# 75%      182.000000
# max      257.000000

# %%
# Adding a new column for "Total Scores"

df["Total_Scores"] = df["Math_Score"] + df["Reading_Score"] + df["Writing_Score"]

# showing the updated dataframe including the Total_Scores column
df.head()
# Out:
#    StudentID             Name   Country  Gender  Age  Math_Score  \
# 0          1  Ifeanyi Mugisha  Zimbabwe  Female   18          99
# 1          2       Yemi Okeke  Tanzania    Male   16          60
# 2          3    Fatou Mugisha  Zimbabwe    Male   15          49
# 3          4   Chinedu Okafor  Ethiopia  Female   17          34
# 4          5        Yemi Moyo   Senegal    Male   16          22
#
#    Reading_Score  Writing_Score                 School Class  Total_Scores
# 0             77             12  Nelson Mandela School  JSS1           188
# 1             29             98         Ubuntu Academy  JSS2           187
# 2             46             84         Ubuntu Academy   SS3           179
# 3             57             45         Ubuntu Academy   SS2           136
# 4             16             38         Ubuntu Academy   SS3            76

# %%
# Adding the column for Percentage Score, readingscore_mathscore_writingscore -> 300
# formula ((Total_Score / 300) * 100) to 2 decimal places 

df["Percentage"] = ((df["Total_Scores"] / 300) * 100).round(2)

df.head()
# Out:
#    StudentID             Name   Country  Gender  Age  Math_Score  \
# 0          1  Ifeanyi Mugisha  Zimbabwe  Female   18          99
# 1          2       Yemi Okeke  Tanzania    Male   16          60
# 2          3    Fatou Mugisha  Zimbabwe    Male   15          49
# 3          4   Chinedu Okafor  Ethiopia  Female   17          34
# 4          5        Yemi Moyo   Senegal    Male   16          22
#
#    Reading_Score  Writing_Score                 School Class  Total_Scores  \
# 0             77             12  Nelson Mandela School  JSS1           188
# 1             29             98         Ubuntu Academy  JSS2           187
# 2             46             84         Ubuntu Academy   SS3           179
# 3             57             45         Ubuntu Academy   SS2           136
# 4             16             38         Ubuntu Academy   SS3            76
#
#    Percentage
# 0       62.67
# 1       62.33
# 2       59.67
# 3       45.33
# 4       25.33

# %%
# Adding a column for status update based on percentage score

df["Status"] = ["Passed" if percentage >= 50
                else "Failed"
                for percentage in df["Percentage"]
                ]

df.head()
# Out:
#    StudentID             Name   Country  Gender  Age  Math_Score  \
# 0          1  Ifeanyi Mugisha  Zimbabwe  Female   18          99
# 1          2       Yemi Okeke  Tanzania    Male   16          60
# 2          3    Fatou Mugisha  Zimbabwe    Male   15          49
# 3          4   Chinedu Okafor  Ethiopia  Female   17          34
# 4          5        Yemi Moyo   Senegal    Male   16          22
#
#    Reading_Score  Writing_Score                 School Class  Total_Scores  \
# 0             77             12  Nelson Mandela School  JSS1           188
# 1             29             98         Ubuntu Academy  JSS2           187
# 2             46             84         Ubuntu Academy   SS3           179
# 3             57             45         Ubuntu Academy   SS2           136
# 4             16             38         Ubuntu Academy   SS3            76
#
#    Percentage  Status
# 0       62.67  Passed
# 1       62.33  Passed
# 2       59.67  Passed
# 3       45.33  Failed
# 4       25.33  Failed

# %%
# renaming 'Math_Score' to 'Mathematics_Score'

df.rename(columns={"Math_Score": "Mathematics_Score"}, inplace=True)

df.head()
# Out:
#    StudentID             Name   Country  Gender  Age  Mathematics_Score  \
# 0          1  Ifeanyi Mugisha  Zimbabwe  Female   18                 99
# 1          2       Yemi Okeke  Tanzania    Male   16                 60
# 2          3    Fatou Mugisha  Zimbabwe    Male   15                 49
# 3          4   Chinedu Okafor  Ethiopia  Female   17                 34
# 4          5        Yemi Moyo   Senegal    Male   16                 22
#
#    Reading_Score  Writing_Score                 School Class  Total_Scores  \
# 0             77             12  Nelson Mandela School  JSS1           188
# 1             29             98         Ubuntu Academy  JSS2           187
# 2             46             84         Ubuntu Academy   SS3           179
# 3             57             45         Ubuntu Academy   SS2           136
# 4             16             38         Ubuntu Academy   SS3            76
#
#    Percentage  Status
# 0       62.67  Passed
# 1       62.33  Passed
# 2       59.67  Passed
# 3       45.33  Failed
# 4       25.33  Failed

# %%
# dropping or removing the school column 

df.drop(columns=["School"], inplace=True)

df.head()
# Out:
#    StudentID             Name   Country  Gender  Age  Mathematics_Score  \
# 0          1  Ifeanyi Mugisha  Zimbabwe  Female   18                 99
# 1          2       Yemi Okeke  Tanzania    Male   16                 60
# 2          3    Fatou Mugisha  Zimbabwe    Male   15                 49
# 3          4   Chinedu Okafor  Ethiopia  Female   17                 34
# 4          5        Yemi Moyo   Senegal    Male   16                 22
#
#    Reading_Score  Writing_Score Class  Total_Scores  Percentage  Status
# 0             77             12  JSS1           188       62.67  Passed
# 1             29             98  JSS2           187       62.33  Passed
# 2             46             84   SS3           179       59.67  Passed
# 3             57             45   SS2           136       45.33  Failed
# 4             16             38   SS3            76       25.33  Failed

# %%
# save dataset to CSV
df.to_csv("updated_student_scores.csv", index=False)
